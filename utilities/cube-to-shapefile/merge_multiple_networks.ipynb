# %%
import os, sys
import pandas as pd
import geopandas as gpd

# %%
folder = 'M:\\Application\\Model One\\RTP2021\\Blueprint\\INPUT_DEVELOPMENT\\Networks'
export_folder = os.path.join(folder, 'network_comparison', 'all_merged')

# %%
plan_networks = {'2015Baseline':  'BlueprintNetworks_62\\net_2015_Baseline\\shapefile',
                 '2050Blueprint': 'BlueprintNetworks_64\\net_2050_Blueprint\\shapefile',
                 '2050Alt1':      'BlueprintNetworks_64\\net_2050_Alt1\\shapefile',
                 '2050Alt2':      'BlueprintNetworks_64\\net_2050_Alt2\\shapefile',
                 '2040Blueprint': 'BlueprintNetworks_64\\net_2040_Blueprint\\shapefile',
                 '2040Alt1':      'BlueprintNetworks_64\\net_2040_Alt1\\shapefile',
                 '2040Alt2':      'BlueprintNetworks_64\\net_2040_Alt2\\shapefile',
                 '2035Blueprint': 'BlueprintNetworks_64\\net_2035_Blueprint\\shapefile',
                 '2035Alt1':      'BlueprintNetworks_64\\net_2035_Alt1\\shapefile',
                 '2035Alt2':      'BlueprintNetworks_64\\net_2035_Alt2\\shapefile',
                 '2030Blueprint': 'BlueprintNetworks_64\\net_2030_Blueprint_TransitCuts_v01\\shapefile',
                 '2030Alt1':      'BlueprintNetworks_64\\net_2030_Alt1\\shapefile',
                 '2030Alt2':      'BlueprintNetworks_64\\net_2030_Alt2\\shapefile',
                 '2025Blueprint': 'BlueprintNetworks_64\\net_2025_Blueprint\\shapefile',
                 '2025Alt1':      'BlueprintNetworks_64\\net_2025_Alt1\\shapefile',
                 '2025Alt2':      'BlueprintNetworks_64\\net_2025_Alt2\\shapefile' 
                }

shapefiles = ['network_links.shp',
              'network_nodes.shp',
              'network_trn_lines.shp',
              'network_trn_links.shp',
              'network_trn_stops.shp']

# %%
for shpfile in shapefiles:
    print(shpfile)
    merged_df = pd.DataFrame()
    for network_scen in plan_networks:
        print(network_scen)
        network_file = os.path.join(folder, plan_networks[network_scen], shpfile)
        network_df = gpd.read_file(network_file)
        print('Read {} with dimension: {}'.format(network_file, network_df.shape))
        network_df['scenario'] = network_scen
        
        merged_df = pd.concat([merged_df, network_df])
        print(merged_df.shape)
    
    merged_df.to_file(os.path.join(export_folder, shpfile))
# Out:
# network_links.shp
# 2015Baseline
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_62\net_2015_Baseline\shapefile\network_links.shp with dimension: (33797, 66)
# (33797, 67)
# 2050Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Blueprint\shapefile\network_links.shp with dimension: (34566, 72)
# (68363, 73)
# 2050Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Alt1\shapefile\network_links.shp with dimension: (34490, 70)
# (102853, 73)
# 2050Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Alt2\shapefile\network_links.shp with dimension: (34588, 72)
# (137441, 73)
# 2040Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Blueprint\shapefile\network_links.shp with dimension: (34486, 73)
# (171927, 74)
# 2040Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Alt1\shapefile\network_links.shp with dimension: (34413, 71)
# (206340, 74)
# 2040Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Alt2\shapefile\network_links.shp with dimension: (34508, 73)
# (240848, 74)
# 2035Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Blueprint\shapefile\network_links.shp with dimension: (34379, 71)
# (275227, 74)
# 2035Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Alt1\shapefile\network_links.shp with dimension: (34348, 71)
# (309575, 74)
# 2035Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Alt2\shapefile\network_links.shp with dimension: (34379, 71)
# (343954, 74)
# 2030Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Blueprint_TransitCuts_v01\shapefile\network_links.shp with dimension: (34241, 70)
# (378195, 74)
# 2030Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Alt1\shapefile\network_links.shp with dimension: (34210, 70)
# (412405, 74)
# 2030Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Alt2\shapefile\network_links.shp with dimension: (34241, 70)
# (446646, 74)
# 2025Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Blueprint\shapefile\network_links.shp with dimension: (34100, 71)
# (480746, 74)
# 2025Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Alt1\shapefile\network_links.shp with dimension: (34070, 71)
# (514816, 74)
# 2025Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Alt2\shapefile\network_links.shp with dimension: (34100, 71)
# (548916, 74)
# network_nodes.shp
# 2015Baseline
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_62\net_2015_Baseline\shapefile\network_nodes.shp with dimension: (14172, 6)
# (14172, 7)
# 2050Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Blueprint\shapefile\network_nodes.shp with dimension: (14344, 6)
# (28516, 7)
# 2050Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Alt1\shapefile\network_nodes.shp with dimension: (14298, 6)
# (42814, 7)
# 2050Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Alt2\shapefile\network_nodes.shp with dimension: (14349, 6)
# (57163, 7)
# 2040Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Blueprint\shapefile\network_nodes.shp with dimension: (14326, 6)
# (71489, 7)
# 2040Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Alt1\shapefile\network_nodes.shp with dimension: (14282, 6)
# (85771, 7)
# 2040Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Alt2\shapefile\network_nodes.shp with dimension: (14331, 6)
# (100102, 7)
# 2035Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Blueprint\shapefile\network_nodes.shp with dimension: (14279, 6)
# (114381, 7)
# 2035Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Alt1\shapefile\network_nodes.shp with dimension: (14253, 6)
# (128634, 7)
# 2035Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Alt2\shapefile\network_nodes.shp with dimension: (14274, 6)
# (142908, 7)
# 2030Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Blueprint_TransitCuts_v01\shapefile\network_nodes.shp with dimension: (14274, 6)
# (157182, 7)
# 2030Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Alt1\shapefile\network_nodes.shp with dimension: (14251, 6)
# (171433, 7)
# 2030Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Alt2\shapefile\network_nodes.shp with dimension: (14269, 6)
# (185702, 7)
# 2025Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Blueprint\shapefile\network_nodes.shp with dimension: (14251, 6)
# (199953, 7)
# 2025Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Alt1\shapefile\network_nodes.shp with dimension: (14228, 6)
# (214181, 7)
# 2025Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Alt2\shapefile\network_nodes.shp with dimension: (14261, 6)
# (228442, 7)
# network_trn_lines.shp
# 2015Baseline
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_62\net_2015_Baseline\shapefile\network_trn_lines.shp with dimension: (1371, 21)
# (1371, 22)
# 2050Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Blueprint\shapefile\network_trn_lines.shp with dimension: (1389, 21)
# (2760, 22)
# 2050Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Alt1\shapefile\network_trn_lines.shp with dimension: (1385, 21)
# (4145, 22)
# 2050Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Alt2\shapefile\network_trn_lines.shp with dimension: (1409, 21)
# (5554, 22)
# 2040Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Blueprint\shapefile\network_trn_lines.shp with dimension: (1387, 21)
# (6941, 22)
# 2040Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Alt1\shapefile\network_trn_lines.shp with dimension: (1383, 21)
# (8324, 22)
# 2040Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Alt2\shapefile\network_trn_lines.shp with dimension: (1405, 21)
# (9729, 22)
# 2035Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Blueprint\shapefile\network_trn_lines.shp with dimension: (1375, 21)
# (11104, 22)
# 2035Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Alt1\shapefile\network_trn_lines.shp with dimension: (1371, 21)
# (12475, 22)
# 2035Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Alt2\shapefile\network_trn_lines.shp with dimension: (1375, 21)
# (13850, 22)
# 2030Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Blueprint_TransitCuts_v01\shapefile\network_trn_lines.shp with dimension: (1363, 21)
# (15213, 22)
# 2030Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Alt1\shapefile\network_trn_lines.shp with dimension: (1359, 21)
# (16572, 22)
# 2030Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Alt2\shapefile\network_trn_lines.shp with dimension: (1363, 21)
# (17935, 22)
# 2025Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Blueprint\shapefile\network_trn_lines.shp with dimension: (1344, 21)
# (19279, 22)
# 2025Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Alt1\shapefile\network_trn_lines.shp with dimension: (1338, 21)
# (20617, 22)
# 2025Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Alt2\shapefile\network_trn_lines.shp with dimension: (1346, 21)
# (21963, 22)
# network_trn_links.shp
# 2015Baseline
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_62\net_2015_Baseline\shapefile\network_trn_links.shp with dimension: (40666, 12)
# (40666, 13)
# 2050Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Blueprint\shapefile\network_trn_links.shp with dimension: (41312, 12)
# (81978, 13)
# 2050Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Alt1\shapefile\network_trn_links.shp with dimension: (41225, 12)
# (123203, 13)
# 2050Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Alt2\shapefile\network_trn_links.shp with dimension: (42128, 12)
# (165331, 13)
# 2040Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Blueprint\shapefile\network_trn_links.shp with dimension: (41391, 12)
# (206722, 13)
# 2040Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Alt1\shapefile\network_trn_links.shp with dimension: (41304, 12)
# (248026, 13)
# 2040Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Alt2\shapefile\network_trn_links.shp with dimension: (42106, 12)
# (290132, 13)
# 2035Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Blueprint\shapefile\network_trn_links.shp with dimension: (41321, 12)
# (331453, 13)
# 2035Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Alt1\shapefile\network_trn_links.shp with dimension: (41240, 12)
# (372693, 13)
# 2035Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Alt2\shapefile\network_trn_links.shp with dimension: (41270, 12)
# (413963, 13)
# 2030Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Blueprint_TransitCuts_v01\shapefile\network_trn_links.shp with dimension: (40412, 12)
# (454375, 13)
# 2030Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Alt1\shapefile\network_trn_links.shp with dimension: (40330, 12)
# (494705, 13)
# 2030Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Alt2\shapefile\network_trn_links.shp with dimension: (40361, 12)
# (535066, 13)
# 2025Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Blueprint\shapefile\network_trn_links.shp with dimension: (40094, 12)
# (575160, 13)
# 2025Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Alt1\shapefile\network_trn_links.shp with dimension: (39984, 12)
# (615144, 13)
# 2025Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Alt2\shapefile\network_trn_links.shp with dimension: (40025, 12)
# (655169, 13)
# network_trn_stops.shp
# 2015Baseline
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_62\net_2015_Baseline\shapefile\network_trn_stops.shp with dimension: (42037, 7)
# (42037, 8)
# 2050Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Blueprint\shapefile\network_trn_stops.shp with dimension: (42701, 7)
# (84738, 8)
# 2050Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Alt1\shapefile\network_trn_stops.shp with dimension: (42610, 7)
# (127348, 8)
# 2050Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2050_Alt2\shapefile\network_trn_stops.shp with dimension: (43537, 7)
# (170885, 8)
# 2040Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Blueprint\shapefile\network_trn_stops.shp with dimension: (42778, 7)
# (213663, 8)
# 2040Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Alt1\shapefile\network_trn_stops.shp with dimension: (42687, 7)
# (256350, 8)
# 2040Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2040_Alt2\shapefile\network_trn_stops.shp with dimension: (43511, 7)
# (299861, 8)
# 2035Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Blueprint\shapefile\network_trn_stops.shp with dimension: (42696, 7)
# (342557, 8)
# 2035Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Alt1\shapefile\network_trn_stops.shp with dimension: (42611, 7)
# (385168, 8)
# 2035Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2035_Alt2\shapefile\network_trn_stops.shp with dimension: (42645, 7)
# (427813, 8)
# 2030Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Blueprint_TransitCuts_v01\shapefile\network_trn_stops.shp with dimension: (41775, 7)
# (469588, 8)
# 2030Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Alt1\shapefile\network_trn_stops.shp with dimension: (41689, 7)
# (511277, 8)
# 2030Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2030_Alt2\shapefile\network_trn_stops.shp with dimension: (41724, 7)
# (553001, 8)
# 2025Blueprint
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Blueprint\shapefile\network_trn_stops.shp with dimension: (41438, 7)
# (594439, 8)
# 2025Alt1
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Alt1\shapefile\network_trn_stops.shp with dimension: (41322, 7)
# (635761, 8)
# 2025Alt2
# Read M:\Application\Model One\RTP2021\Blueprint\INPUT_DEVELOPMENT\Networks\BlueprintNetworks_64\net_2025_Alt2\shapefile\network_trn_stops.shp with dimension: (41371, 7)
# (677132, 8)
